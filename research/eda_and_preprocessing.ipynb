# %%
This notebook should demonstrate:

Text Cleaning: Removing HTML tags, ticket headers (e.g., "RE:"), and stop words from descriptions.

Imbalance Analysis: Showing that "Critical" tickets are rare (meaning the RAG needs to be extra careful with them).

Keyword Extraction: Using TF-IDF or WordClouds to show the most frequent technical issues.
